# %%
from matplotlib import pyplot as plt
import numpy as np
from fracturetoughness import FractureToughness
from threepointbend import ThreePointBend

# %%
# notched samples

# cast
notched_cast_4 = FractureToughness('Thesis_Samples_Data/Notched_Cast_4/Notched_Cast_4.csv', 90, 25.87, 32.31, 0.97, cmp=1.99)
notched_cast_5 = FractureToughness('Thesis_Samples_Data/Notched_Cast_5/Notched_Cast_5.csv', 90, 27.34, 32.17, 0.97, cmp=2.02)
notched_cast_6 = FractureToughness('Thesis_Samples_Data/Notched_Cast_6/Notched_Cast_6.csv', 90, 26.15, 32.35, 0.97, cmp=2.02)

# solid
notched_solid_4 = FractureToughness('Thesis_Samples_Data/Notched_Solid_4/Notched_Solid_4.csv', 90, 25.08, 41.76, 0.97, cmp=1.86)
notched_solid_5 = FractureToughness('Thesis_Samples_Data/Notched_Solid_5/Notched_Solid_5.csv', 90, 26.5, 39.97, 0.97, cmp=1.84)
notched_solid_6 = FractureToughness('Thesis_Samples_Data/Notched_Solid_6/Notched_Solid_6.csv', 90, 23.61, 44.77, 0.97, cmp=1.83)

# layered
notched_layered_4 = FractureToughness('Thesis_Samples_Data/Notched_Layered_4/Notched_Layered_4.csv', 90, 23.1, 43.76, 0.97, cmp=1.48, multi=True)
notched_layered_5 = FractureToughness('Thesis_Samples_Data/Notched_Layered_5_(precracked)/Notched_Layered_5_(precracked).csv', 90, 24.92, 40.43, 0.97, cmp=1.46, multi=True)
notched_layered_6 = FractureToughness('Thesis_Samples_Data/Notched_Layered_6/Notched_Layered_6.csv', 90, 25.23, 40.68, 0.97, cmp=1.46, multi=True)

# display cast
notched_cast_4.display_peaks()
notched_cast_5.display_peaks()
notched_cast_6.display_peaks()
# Out:
# [1148 2379 2460]
# [2112]
# [1697]

# %%
notched_cast_4.do_analysis(2379)
notched_cast_5.do_analysis(2112)
notched_cast_6.do_analysis(1697)

cast_K_ic = np.array([notched_cast_4.K_ic, notched_cast_5.K_ic, notched_cast_6.K_ic])
cast_K_ic_normalized = np.array([notched_cast_4.K_ic_normalized, notched_cast_5.K_ic_normalized, notched_cast_6.K_ic_normalized])


cast_K_jc = np.array([notched_cast_4.K_jc_overall, notched_cast_5.K_jc_overall, notched_cast_6.K_jc_overall])
cast_K_jc_normalized = np.array([notched_cast_4.K_jc_overall_normalized, notched_cast_5.K_jc_overall_normalized, notched_cast_6.K_jc_overall_normalized])


cast_K_ic_MOR = np.array([notched_cast_4.K_ic_MOR, notched_cast_5.K_ic_MOR, notched_cast_6.K_ic_MOR])
cast_K_jc_MOR = np.array([notched_cast_4.K_jc_overall_MOR, notched_cast_5.K_jc_overall_MOR, notched_cast_6.K_jc_overall_MOR])

cast_K_jc_offset = np.array([notched_cast_4.K_jc_overall_offset, notched_cast_5.K_jc_overall_offset, notched_cast_6.K_jc_overall_offset])
cast_K_jc_offset_normalized = np.array([notched_cast_4.K_jc_overall_offset_normalized, notched_cast_5.K_jc_overall_offset_normalized, notched_cast_6.K_jc_overall_offset_normalized])

# %%
# display solid
notched_solid_4.display_peaks()
notched_solid_5.display_peaks()
notched_solid_6.display_peaks()
# Out:
# [1765 2063 6693]
# [1915 2161]
# [1449 1604 1757 1945]

# %%
notched_solid_4.do_analysis(2063)
notched_solid_5.do_analysis(1915)
notched_solid_6.do_analysis(1449)

solid_K_ic = np.array([notched_solid_4.K_ic, notched_solid_5.K_ic, notched_solid_6.K_ic])
solid_K_ic_normalized = np.array([notched_solid_4.K_ic_normalized, notched_solid_5.K_ic_normalized, notched_solid_6.K_ic_normalized])

solid_K_jc = np.array([notched_solid_4.K_jc_overall, notched_solid_5.K_jc_overall, notched_solid_6.K_jc_overall])
solid_K_jc_normalized = np.array([notched_solid_4.K_jc_overall_normalized, notched_solid_5.K_jc_overall_normalized, notched_solid_6.K_jc_overall_normalized])

solid_K_ic_MOR = np.array([notched_solid_4.K_ic_MOR, notched_solid_5.K_ic_MOR, notched_solid_6.K_ic_MOR])
solid_K_jc_MOR = np.array([notched_solid_4.K_jc_overall_MOR, notched_solid_5.K_jc_overall_MOR, notched_solid_6.K_jc_overall_MOR])


solid_K_jc_offset = np.array([notched_solid_4.K_jc_overall_offset, notched_solid_5.K_jc_overall_offset, notched_solid_6.K_jc_overall_offset])
solid_K_jc_offset_normalized = np.array([notched_solid_4.K_jc_overall_offset_normalized, notched_solid_5.K_jc_overall_offset_normalized, notched_solid_6.K_jc_overall_offset_normalized])

# %%
# display layered
notched_layered_4.display_peaks()
notched_layered_5.display_peaks()
notched_layered_6.display_peaks()
# Out:
# [ 2245  3319  5749  6591  6773  7252  7580  8296  8987  9225  9693 10168
#  10752 11352 11675 12223 12803 13310 13568 13861 14291 14634 15013 16168
#  16637 16788 17146 18348 24328 25917 26630 27094 27417 27850 28629 29816
#  30720 32949 33752 34913 37485 38298 38536 38965 39389]
# [ 1443  2062  3455  4052  4312  5972  7259  9770 15419 17083]
# [   59  4025  4886 11140 12972 13568 14038 20446 22600 30090]

# %%
notched_layered_4.do_analysis(2245, stop_index=18755) #18755
notched_layered_5.do_analysis(1443, stop_index=17100)
notched_layered_6.do_analysis(4025, stop_index=30100)

layered_K_ic = np.array([notched_layered_4.K_ic, notched_layered_6.K_ic])
layered_K_ic_normalized = np.array([notched_layered_4.K_ic_normalized, notched_layered_6.K_ic_normalized])

layered_K_jc = np.array([notched_layered_4.K_jc_overall, notched_layered_6.K_jc_overall])
layered_K_jc_normalized = np.array([notched_layered_4.K_jc_overall_normalized, notched_layered_6.K_jc_overall_normalized])

layered_K_ic_MOR = np.array([notched_layered_4.K_ic_MOR, notched_layered_6.K_ic_MOR])
layered_K_jc_MOR = np.array([notched_layered_4.K_jc_overall_MOR, notched_layered_6.K_jc_overall_MOR])

layered_K_jc_offset = np.array([notched_layered_4.K_jc_overall_offset, notched_layered_6.K_jc_overall_offset])
layered_K_jc_offset_normalized = np.array([notched_layered_4.K_jc_overall_offset_normalized, notched_layered_6.K_jc_overall_offset_normalized])

# %%
# unnotched samples

# cast
flexural_cast_1 = ThreePointBend('Thesis_Samples_Data/Flexural_Cast_1/Flexural_Cast_1.csv', 90, 28.03, 32.19, cmp=2.01)
flexural_cast_2 = ThreePointBend('Thesis_Samples_Data/Flexural_Cast_2/Flexural_Cast_2.csv', 90, 28.3, 32.24, cmp=2.02)
flexural_cast_3 = ThreePointBend('Thesis_Samples_Data/Flexural_Cast_3/Flexural_Cast_3.csv', 90, 28.42, 32.18, cmp=2.01)

# solid
flexural_solid_1 = ThreePointBend('Thesis_Samples_Data/Flexural_Solid_1/Flexural_Solid_1.csv', 90, 19.86, 51.75, cmp=1.90)
flexural_solid_2 = ThreePointBend('Thesis_Samples_Data/Flexural_Solid_2/Flexural_Solid_2.csv', 90, 26.37, 39.97, cmp=1.83)
flexural_solid_3 = ThreePointBend('Thesis_Samples_Data/Flexural_Solid_3/Flexural_Solid_3.csv', 90, 25.2, 41.46, cmp=1.85)

# layered
flexural_layered_1 = ThreePointBend('Thesis_Samples_Data/Flexural_Layered_1/Flexural_Layered_1.csv', 90, 24.26, 42.11, cmp=1.48, multi=True)
flexural_layered_2 = ThreePointBend('Thesis_Samples_Data/Flexural_Layered_2/Flexural_Layered_2.csv', 90, 23.04, 43.37, cmp=1.49, multi=True)
flexural_layered_3 = ThreePointBend('Thesis_Samples_Data/Flexural_Layered_3/Flexural_Layered_3.csv', 90, 23.72, 42.84, cmp=1.49, multi=True)

# rebar
flexural_rebar_1 = ThreePointBend('Thesis_Samples_Data/Flexural_Rebar_1/Flexural_Rebar_1.csv', 90, 28.65, 45.33, cmp=1.71, multi=True)
flexural_rebar_2 = ThreePointBend('Thesis_Samples_Data/Flexural_Rebar_2/Flexural_Rebar_2.csv', 90, 26.01, 47.68, cmp=1.75, multi=True)
flexural_rebar_3 = ThreePointBend('Thesis_Samples_Data/Flexural_Rebar_3/Flexural_Rebar_3.csv', 90, 26.51, 48.19, cmp=1.73, multi=True)

flexural_cast_1.display_peaks()
flexural_cast_2.display_peaks()
flexural_cast_3.display_peaks()
# Out:
# [1750 1766 1911 2032]
# [1887 2272]
# [2198]

# %%
flexural_cast_1.do_analysis(1766)
flexural_cast_2.do_analysis(1887)
flexural_cast_3.do_analysis(2198)

cast_MOR = np.array([flexural_cast_1.MOR, flexural_cast_3.MOR, flexural_cast_3.MOR])
cast_MOR_normalized = np.array([flexural_cast_1.MOR_normalized, flexural_cast_3.MOR_normalized, flexural_cast_3.MOR_normalized])


cast_toughness_overall = np.array([flexural_cast_1.toughness_overall, flexural_cast_2.toughness_overall, flexural_cast_3.toughness_overall])
cast_toughness_overall_normalized = np.array([flexural_cast_1.toughness_overall_normalized, flexural_cast_2.toughness_overall_normalized, flexural_cast_3.toughness_overall_normalized])
cast_toughness_stress = np.array([flexural_cast_1.toughness_stress, flexural_cast_2.toughness_stress, flexural_cast_3.toughness_stress])
cast_toughness_stress_normalized = np.array([flexural_cast_1.toughness_stress_normalized, flexural_cast_2.toughness_stress_normalized, flexural_cast_3.toughness_stress_normalized])

# %%
flexural_solid_1.display_peaks()
flexural_solid_2.display_peaks()
flexural_solid_3.display_peaks()
# Out:
# [2194 2279 2436 2482 2603 2679 9037 9722]
# [1025 2034]
# [1415 1515 1597 1765 1902 2058]

# %%
flexural_solid_1.do_analysis(2279)
flexural_solid_2.do_analysis(2034)
flexural_solid_3.do_analysis(1415)

solid_MOR = np.array([flexural_solid_1.MOR, flexural_solid_3.MOR, flexural_solid_3.MOR])
solid_MOR_normalized = np.array([flexural_solid_1.MOR_normalized, flexural_solid_3.MOR_normalized, flexural_solid_3.MOR_normalized])


solid_toughness_overall = np.array([flexural_solid_1.toughness_overall, flexural_solid_2.toughness_overall, flexural_solid_3.toughness_overall])
solid_toughness_overall_normalized = np.array([flexural_solid_1.toughness_overall_normalized, flexural_solid_2.toughness_overall_normalized, flexural_solid_3.toughness_overall_normalized])
solid_toughness_stress = np.array([flexural_solid_1.toughness_stress, flexural_solid_2.toughness_stress, flexural_solid_3.toughness_stress])
solid_toughness_stress_normalized = np.array([flexural_solid_1.toughness_stress_normalized, flexural_solid_2.toughness_stress_normalized, flexural_solid_3.toughness_stress_normalized])

# %%
plt.figure(figsize=(15, 7))

plt.suptitle('Example Load-Displacement Outputs', fontsize=24)

sub = plt.subplot(1, 2, 1)
sub.plot(flexural_layered_2.crosshead, flexural_layered_2.load, color='c', markerfacecolor='b', markeredgewidth=0,marker='.',markersize=5)
plt.xlabel('Crosshead Displacement (mm)', fontsize=16)
plt.ylabel('Load (N)', fontsize=16)
plt.title('Cement-Silicone', fontsize=20)


sub = plt.subplot(1, 2, 2)
sub.plot(flexural_rebar_1.crosshead, flexural_rebar_1.load, color='#ff8000', markerfacecolor='#ffb266', markeredgewidth=0,marker='.',markersize=5)
plt.xlabel('Crosshead Displacement (mm)', fontsize=16)
plt.ylabel('Load (N)', fontsize=16)
plt.title('Cement-PLA', fontsize=20)


# flexural_layered_2.display_peaks()
# flexural_rebar_1.display_peaks()
# Out:
# Text(0.5, 1.0, 'Cement-PLA')

# %%
flexural_layered_1.display_peaks()
flexural_layered_2.display_peaks()
flexural_layered_3.display_peaks()
# Out:
# [  335   456   875  2250  2467  2704  2820  6337  6630  7602  8190  8831
#   9360 10764 11033 11286 12120 15581 15959 16846 18691 22243 23156 23641
#  23944 24554 24953 25833 26886 27680 28252 29829 30138 35995 36961 38684
#  41097 41778 42827 43676 44136 44717 45344 46424 47471 48352 49481 50769
#  51278 55028 55436 61248 61757 65186]
# [  558  4058  4250  4346  4781  5013  5190  7958  8297  8475  9981 10349
#  11516 11577 12911 14419 17438 35847]
# [ 1430  2176  3493  5924  7694  8270  8951  9570 23080 23473 24675 25538
#  26204 26784 30856 34129 39909 40347 41305 42592 43154 44867 45141 46400
#  46688 49090 49465 50992 51300 52778 54027 55717 58048 60093 63318]

# %%
flexural_layered_1.do_analysis(6337, stop_index=31000)
flexural_layered_2.do_analysis(4250, stop_index=15000)
flexural_layered_3.do_analysis(1430, stop_index=28050)


layered_MOR = np.array([flexural_layered_1.MOR, flexural_layered_3.MOR, flexural_layered_3.MOR])
layered_MOR_normalized = np.array([flexural_layered_1.MOR_normalized, flexural_layered_3.MOR_normalized, flexural_layered_3.MOR_normalized])


layered_toughness_overall = np.array([flexural_layered_1.toughness_overall, flexural_layered_2.toughness_overall, flexural_layered_3.toughness_overall])
layered_toughness_overall_normalized = np.array([flexural_layered_1.toughness_overall_normalized, flexural_layered_2.toughness_overall_normalized, flexural_layered_3.toughness_overall_normalized])
layered_toughness_stress = np.array([flexural_layered_1.toughness_stress, flexural_layered_2.toughness_stress, flexural_layered_3.toughness_stress])
layered_toughness_stress_normalized = np.array([flexural_layered_1.toughness_stress_normalized, flexural_layered_2.toughness_stress_normalized, flexural_layered_3.toughness_stress_normalized])

# %%
flexural_rebar_1.display_peaks()
flexural_rebar_2.display_peaks()
flexural_rebar_3.display_peaks()
# Out:
# [ 2000  2820  3079  3406  3705  5062  5404  5509  5642  6920  6975  7360
#   7703  9115 11620 11966 12112 12820 13438 15291 16155 16626 16661 17662
#  20654 21206 21616 22996 23561 23970 26679 27395 30006 30615 31283 32014
#  32680 32812 42842 43262 43636 44051 44698 45268 47636 49646 50029 50191
#  51049 51226 52306 54106 54589 55230 56059 56195 58056]
# [ 2473  2823  3315  4107  4431  4753  5843  6657  6907  6994  7443  7614
#   7943  8262  8479  8651 10016 10354 13670 15664 16074 16225 19958 21280
#  21750 22179 22973 23049 24848 26629 27261 27458 28293 28642 29465 29905
#  31131 31357 32615 32983 33620 33886 35489 35791 36673 38051 38344 39068
#  39412 40872 40963 41993 42226 42443 42914 43424 43651 43884 44293 45439
#  47431 47877 48544 49706 50429 50904 52424 52754 53037 53319 53754 55625
#  55882 56466 58002 59252 60598 61027 61396 61638 62208 64435 65633 67804
#  70012 70678 70795 72530 72606 73493 74451 76000 77313 78095 78897 80330
# ...

# %%
flexural_rebar_1.do_analysis(3079, stop_index=34250)
flexural_rebar_2.do_analysis(4107, stop_index=81000)
flexural_rebar_3.do_analysis(5048, stop_index=80050)

rebar_MOR = np.array([flexural_rebar_1.MOR, flexural_rebar_3.MOR, flexural_rebar_3.MOR])
rebar_MOR_normalized = np.array([flexural_rebar_1.MOR_normalized, flexural_rebar_3.MOR_normalized, flexural_rebar_3.MOR_normalized])


rebar_toughness_overall = np.array([flexural_rebar_1.toughness_overall, flexural_rebar_2.toughness_overall, flexural_rebar_3.toughness_overall])
rebar_toughness_overall_normalized = np.array([flexural_rebar_1.toughness_overall_normalized, flexural_rebar_2.toughness_overall_normalized, flexural_rebar_3.toughness_overall_normalized])
rebar_toughness_stress = np.array([flexural_rebar_1.toughness_stress, flexural_rebar_2.toughness_stress, flexural_rebar_3.toughness_stress])
rebar_toughness_stress_normalized = np.array([flexural_rebar_1.toughness_stress_normalized, flexural_rebar_2.toughness_stress_normalized, flexural_rebar_3.toughness_stress_normalized])

# %%
barWidth = 0.25
fig, ax = plt.subplots(figsize=(15, 10))

plt.suptitle('Fracture Toughness Values', fontsize=24)

cast = [np.mean(cast_K_ic), np.mean(cast_K_ic_normalized), np.mean(cast_K_jc), np.mean(cast_K_jc_normalized)]
solid = [np.mean(solid_K_ic), np.mean(solid_K_ic_normalized), np.mean(solid_K_jc), np.mean(solid_K_jc_normalized)]
layered = [np.mean(layered_K_ic), np.mean(layered_K_ic_normalized), np.mean(layered_K_jc), np.mean(layered_K_jc_normalized)] 

# Set position of bar on X axis
br1 = np.arange(len(cast))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]

n = 3
cast_err = (1.96/np.sqrt(n))*np.array([np.std(cast_K_ic), np.std(cast_K_ic_normalized), np.std(cast_K_jc), np.std(cast_K_jc_normalized)])
solid_err = (1.96/np.sqrt(n))*np.array([np.std(solid_K_ic), np.std(solid_K_ic_normalized), np.std(solid_K_jc), np.std(solid_K_jc_normalized)])
layered_err = (1.96/np.sqrt(10))*np.array([np.std(layered_K_ic), np.std(layered_K_ic_normalized), np.std(layered_K_jc), np.std(layered_K_jc_normalized)])

# Make the plot
bar1 = ax.barh(br1, cast, color='#3399ff', height=barWidth, edgecolor ='grey', label ='Cast Cement', xerr=cast_err, capsize=5)
ax.bar_label(bar1, fmt='%.3f', padding=5)
bar2 = ax.barh(br2, solid, color='#ff2f2f', height=barWidth, edgecolor ='grey', label ='3DP Cement', xerr=solid_err, capsize=5)
ax.bar_label(bar2, fmt='%.3f', padding=5)
bar3 = ax.barh(br3, layered, color='#36a841', height=barWidth, edgecolor ='grey', label ='3DP Cement-Silicone', xerr=layered_err, capsize=5)
ax.bar_label(bar3, fmt='%.3f', padding=5)

# Adding Xticks
plt.xlabel('MPa*mm^1.5', fontsize=16)
plt.ylabel('', fontsize=16)
plt.yticks([r + barWidth for r in range(len(cast))], ['Kic', 'Normalized Kic', 'Kjc', 'Normalized Kjc'], fontsize=16)
 
plt.legend(loc='best', fontsize=12)
plt.show()

# %%
barWidth = 0.25
fig, ax = plt.subplots(figsize=(15, 10))

plt.suptitle('MOR Values', fontsize=24)

cast = np.array([np.mean(cast_MOR), np.mean(cast_MOR_normalized)])
solid = np.array([np.mean(solid_MOR), np.mean(solid_MOR_normalized)])
layered = np.array([np.mean(layered_MOR), np.mean(layered_MOR_normalized)])
rebar = np.array([np.mean(rebar_MOR), np.mean(rebar_MOR_normalized)])


# Set position of bar on X axis
br1 = np.arange(len(cast))*(1+barWidth)
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
br4 = [x + barWidth for x in br3]

n = 3
cast_err = (1.96/np.sqrt(n))*np.array([np.std(cast_MOR), np.std(cast_MOR_normalized)])
solid_err = (1.96/np.sqrt(n))*np.array([np.std(solid_MOR), np.std(solid_MOR_normalized)])
layered_err = (1.96/np.sqrt(n))*np.array([np.std(layered_MOR), np.std(layered_MOR_normalized)])
rebar_err = (1.96/np.sqrt(n))*np.array([np.std(rebar_MOR), np.std(rebar_MOR_normalized)])

# Make the plot
bar1 = ax.barh(br1, cast, color='#3399ff', height=barWidth, edgecolor ='grey', label ='Cast Cement', xerr=cast_err, capsize=5)
ax.bar_label(bar1, fmt='%.3f', padding=5)
bar2 = ax.barh(br2, solid, color='#ff2f2f', height=barWidth, edgecolor ='grey', label ='3DP Cement', xerr=solid_err, capsize=5)
ax.bar_label(bar2, fmt='%.3f', padding=5)
bar3 = ax.barh(br3, layered, color='#36a841', height=barWidth, edgecolor ='grey', label ='3DP Cement-Silicone', xerr=layered_err, capsize=5)
ax.bar_label(bar3, fmt='%.3f', padding=5)
bar4 = ax.barh(br4, rebar, color='#ffb266', height=barWidth, edgecolor ='grey', label ='3DP Concrete-PLA', xerr=rebar_err, capsize=5)
ax.bar_label(bar4, fmt='%.2f', padding=5)

# Adding Xticks
plt.xlabel('MPa', fontsize=16)
plt.ylabel('', fontsize=16)
plt.yticks([1.5*barWidth, 1+2.5*barWidth], ['MOR', 'Normalized MOR'], fontsize=16)

 
plt.legend()
plt.show()

# %%
barWidth = 0.25
fig, ax = plt.subplots(figsize=(15, 10))

plt.suptitle('Toughness Values', fontsize=24)


cast = np.array([np.mean(cast_toughness_overall), np.mean(cast_toughness_overall_normalized), np.mean(cast_toughness_stress), np.mean(cast_toughness_stress_normalized)])
solid = np.array([np.mean(solid_toughness_overall), np.mean(solid_toughness_overall_normalized), np.mean(solid_toughness_stress), np.mean(solid_toughness_stress_normalized)])
layered = np.array([np.mean(layered_toughness_overall), np.mean(layered_toughness_overall_normalized), np.mean(layered_toughness_stress), np.mean(layered_toughness_stress_normalized)])
rebar = np.array([np.mean(rebar_toughness_overall), np.mean(rebar_toughness_overall_normalized), np.mean(rebar_toughness_stress), np.mean(rebar_toughness_stress_normalized)])


# Set position of bar on X axis
br1 = np.arange(len(cast))*(1+barWidth)
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
br4 = [x + barWidth for x in br3]

n = 3
cast_err = (1.96/np.sqrt(n))*np.array([np.std(cast_toughness_overall), np.std(cast_toughness_overall_normalized), np.std(cast_toughness_stress), np.std(cast_toughness_stress_normalized)])
solid_err = (1.96/np.sqrt(n))*np.array([np.std(solid_toughness_overall), np.std(solid_toughness_overall_normalized), np.std(solid_toughness_stress), np.std(solid_toughness_stress_normalized)])
layered_err = (1.96/np.sqrt(n))*np.array([np.std(layered_toughness_overall), np.std(layered_toughness_overall_normalized), np.std(layered_toughness_stress), np.std(layered_toughness_stress_normalized)])
rebar_err = (1.96/np.sqrt(n))*np.array([np.std(rebar_toughness_overall), np.std(rebar_toughness_overall_normalized), np.std(rebar_toughness_stress), np.std(rebar_toughness_stress_normalized)])

# Make the plot
bar1 = ax.barh(br1, cast, color='b', height=barWidth, edgecolor ='grey', label ='Cast Concrete', xerr=cast_err, capsize=5)
ax.bar_label(bar1, fmt='%.2f', padding=5)
bar2 = ax.barh(br2, solid, color='r', height=barWidth, edgecolor ='grey', label ='3DP Concrete', xerr=solid_err, capsize=5)
ax.bar_label(bar2, fmt='%.2f', padding=5)
bar3 = ax.barh(br3, layered, color='g', height=barWidth, edgecolor ='grey', label ='3DP Concrete-Silicone', xerr=layered_err, capsize=5)
ax.bar_label(bar3, fmt='%.2f', padding=5)
bar4 = ax.barh(br4, rebar, color='#ffb266', height=barWidth, edgecolor ='grey', label ='3DP Concrete-PLA', xerr=rebar_err, capsize=5)
ax.bar_label(bar4, fmt='%.2f', padding=5)

# Adding Xticks
plt.xlabel('', fontsize=16)
plt.ylabel('', fontsize=16)
plt.yticks([1.35*r + 0.25*barWidth for r in range(len(cast))], ['Overall Toughness', 'Normalized Overall Toughness', 'Stress Toughness', 'Normalized Stress Toughness'], fontsize=16)
 
plt.legend()
plt.show()

# %%
barWidth = 0.25
fig, ax = plt.subplots(figsize=(15, 10))

plt.suptitle('Stress-Based Toughness Values', fontsize=24)


cast = np.array([np.mean(cast_toughness_stress), np.mean(cast_toughness_stress_normalized)])
solid = np.array([np.mean(solid_toughness_stress), np.mean(solid_toughness_stress_normalized)])
layered = np.array([np.mean(layered_toughness_stress), np.mean(layered_toughness_stress_normalized)])
rebar = np.array([np.mean(rebar_toughness_stress), np.mean(rebar_toughness_stress_normalized)])


# Set position of bar on X axis
br1 = np.arange(len(cast))*(1+barWidth)
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
br4 = [x + barWidth for x in br3]

n = 3
cast_err = (1.96/np.sqrt(n))*np.array([np.std(cast_toughness_stress), np.std(cast_toughness_stress_normalized)])
solid_err = (1.96/np.sqrt(n))*np.array([np.std(solid_toughness_stress), np.std(solid_toughness_stress_normalized)])
layered_err = (1.96/np.sqrt(n))*np.array([np.std(layered_toughness_stress), np.std(layered_toughness_stress_normalized)])
rebar_err = (1.96/np.sqrt(n))*np.array([np.std(rebar_toughness_stress), np.std(rebar_toughness_stress_normalized)])

# Make the plot
bar1 = ax.barh(br1, cast, color='#3399ff', height=barWidth, edgecolor ='grey', label ='Cast Cement', xerr=cast_err, capsize=5)
ax.bar_label(bar1, fmt='%.3f', padding=5)
bar2 = ax.barh(br2, solid, color='#ff2f2f', height=barWidth, edgecolor ='grey', label ='3DP Cement', xerr=solid_err, capsize=5)
ax.bar_label(bar2, fmt='%.3f', padding=5)
bar3 = ax.barh(br3, layered, color='#36a841', height=barWidth, edgecolor ='grey', label ='3DP Cement-Silicone', xerr=layered_err, capsize=5)
ax.bar_label(bar3, fmt='%.3f', padding=5)
bar4 = ax.barh(br4, rebar, color='#ffb266', height=barWidth, edgecolor ='grey', label ='3DP Concrete-PLA', xerr=rebar_err, capsize=5)
ax.bar_label(bar4, fmt='%.2f', padding=5)

# Adding Xticks
plt.xlabel('MPa*mm', fontsize=16)
plt.ylabel('', fontsize=16)
plt.yticks([1.5*barWidth, 1+2.5*barWidth], ['Stress Toughness', 'Normalized Stress Toughness'], fontsize=16)
 
plt.legend(loc='lower right', fontsize=12)
plt.show()

# %%
barWidth = 0.25
fig, ax = plt.subplots(figsize=(10, 10))

plt.suptitle('Stress-Based Toughness Values', fontsize=24)


cast = np.array([np.mean(cast_toughness_stress), np.mean(cast_toughness_stress_normalized)])
solid = np.array([np.mean(solid_toughness_stress), np.mean(solid_toughness_stress_normalized)])
layered = np.array([np.mean(layered_toughness_stress), np.mean(layered_toughness_stress_normalized)])


# Set position of bar on X axis
br1 = np.arange(len(cast))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]

n = 3
cast_err = (1.96/np.sqrt(n))*np.array([np.std(cast_toughness_stress), np.std(cast_toughness_stress_normalized)])
solid_err = (1.96/np.sqrt(n))*np.array([np.std(solid_toughness_stress), np.std(solid_toughness_stress_normalized)])
layered_err = (1.96/np.sqrt(n))*np.array([np.std(layered_toughness_stress), np.std(layered_toughness_stress_normalized)])

# Make the plot
bar1 = ax.barh(br1, cast, color='#3399ff', height=barWidth, edgecolor ='grey', label ='Cast Cement', xerr=cast_err, capsize=5)
ax.bar_label(bar1, fmt='%.3f', padding=5)
bar2 = ax.barh(br2, solid, color='#ff2f2f', height=barWidth, edgecolor ='grey', label ='3DP Cement', xerr=solid_err, capsize=5)
ax.bar_label(bar2, fmt='%.3f', padding=5)
bar3 = ax.barh(br3, layered, color='#36a841', height=barWidth, edgecolor ='grey', label ='3DP Cement-Silicone', xerr=layered_err, capsize=5)
ax.bar_label(bar3, fmt='%.3f', padding=5)

# Adding ticks
plt.xlabel('MPa*mm', fontsize=16)
plt.ylabel('', fontsize=16)
plt.yticks([r + barWidth for r in range(len(cast))], ['Stress Toughness', 'Normalized Stress Toughness'], fontsize=16)
 
plt.legend()
plt.show()

# %%
barWidth = 0.25
fig, ax = plt.subplots(figsize=(15, 10))

plt.suptitle('MOR-Normalized Fracture Toughness Values', fontsize=24)

cast = [np.mean(cast_K_ic_MOR), np.mean(cast_K_jc_MOR)]
solid = [np.mean(solid_K_ic_MOR), np.mean(solid_K_jc_MOR)]
layered = [np.mean(layered_K_ic_MOR), np.mean(layered_K_jc_MOR)] 

# Set position of bar on X axis
br1 = np.arange(len(cast))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]

n = 3
cast_err = (1.96/np.sqrt(n))*np.array([np.std(cast_K_ic_MOR), np.std(cast_K_jc_MOR)])
solid_err = (1.96/np.sqrt(n))*np.array([np.std(solid_K_ic_MOR), np.std(solid_K_jc_MOR)])
layered_err = (1.96/np.sqrt(2))*np.array([np.std(layered_K_ic_MOR), np.std(layered_K_jc_MOR)])

# Make the plot
bar1 = ax.barh(br1, cast, color='#3399ff', height=barWidth, edgecolor ='grey', label ='Cast Cement', xerr=cast_err, capsize=5)
ax.bar_label(bar1, fmt='%.3f', padding=5)
bar2 = ax.barh(br2, solid, color='#ff2f2f', height=barWidth, edgecolor ='grey', label ='3DP Cement', xerr=solid_err, capsize=5)
ax.bar_label(bar2, fmt='%.3f', padding=5)
bar3 = ax.barh(br3, layered, color='#36a841', height=barWidth, edgecolor ='grey', label ='3DP Cement-Silicone', xerr=layered_err, capsize=5)
ax.bar_label(bar3, fmt='%.3f', padding=5)

# Adding Xticks
plt.xlabel('MPa*mm^1.5', fontsize=16)
plt.ylabel('', fontsize=16)
plt.yticks([r + barWidth for r in range(len(cast))], ['Kic_MOR', 'Kjc_MOR'], fontsize=16)
 
plt.legend(loc='best')
plt.show()

# %%
barWidth = 0.25
fig, ax = plt.subplots(figsize=(8, 6))

plt.suptitle('Net Kjc Values', fontsize=24)

cast = [0]
solid = [np.mean(solid_K_jc_offset)]
layered = [np.mean(layered_K_jc_offset)] 

# Set position of bar on X axis
br1 = np.arange(len(cast))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]

n = 3
cast_err = (1.96/np.sqrt(n))*np.array([0])
solid_err = (1.96/np.sqrt(n))*np.array([np.std(solid_K_jc_offset)])
layered_err = (1.96/np.sqrt(3))*np.array([np.std(layered_K_jc_offset)])

# Make the plot
bar1 = ax.barh(br1, cast, color='#3399ff', height=barWidth, edgecolor ='grey', label ='Cast Cement', xerr=cast_err, capsize=5)
ax.bar_label(bar1, fmt='%.3f', padding=5)
bar2 = ax.barh(br2, solid, color='#ff2f2f', height=barWidth, edgecolor ='grey', label ='3DP Cement', xerr=solid_err, capsize=5)
ax.bar_label(bar2, fmt='%.3f', padding=5)
bar3 = ax.barh(br3, layered, color='#36a841', height=barWidth, edgecolor ='grey', label ='3DP Cement-Silicone', xerr=layered_err, capsize=5)
ax.bar_label(bar3, fmt='%.3f', padding=5)
# Adding Xticks
plt.xlabel('MPa*mm^4.5*g^-1', fontsize=16)
plt.ylabel('', fontsize=16)
plt.yticks([r + barWidth for r in range(len(cast))], ['Specific (Kjc-Kic)'], fontsize=16)
 
plt.legend(loc='lower right', fontsize=12)
plt.show()


np.std(layered_K_jc_offset)
# Out:
# 0.5765703248736045

# %%
arWidth = 0.25
fig, ax = plt.subplots(figsize=(8, 6))

plt.suptitle('Fracture Toughness Values', fontsize=24)

cast = [np.mean(cast_K_ic), 0]
solid = [np.mean(solid_K_ic), np.mean(solid_K_jc)]
layered = [np.mean(layered_K_ic), np.mean(layered_K_jc)] 

# Set position of bar on X axis
br1 = np.arange(len(cast))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]

n = 3
cast_err = (1.96/np.sqrt(n))*np.array([np.std(cast_K_ic), 0])
solid_err = (1.96/np.sqrt(n))*np.array([np.std(solid_K_ic), np.std(solid_K_jc)])
layered_err = (1.96/np.sqrt(3))*np.array([np.std(layered_K_ic), np.std(layered_K_jc)])

# Make the plot
bar1 = ax.barh(br1, cast, color='#3399ff', height=barWidth, edgecolor ='grey', label ='Cast Cement', xerr=cast_err, capsize=5)
ax.bar_label(bar1, fmt='%.3f', padding=5)
bar2 = ax.barh(br2, solid, color='#ff2f2f', height=barWidth, edgecolor ='grey', label ='3DP Cement', xerr=solid_err, capsize=5)
ax.bar_label(bar2, fmt='%.3f', padding=5)
bar3 = ax.barh(br3, layered, color='#36a841', height=barWidth, edgecolor ='grey', label ='3DP Cement-Silicone', xerr=layered_err, capsize=5)
ax.bar_label(bar3, fmt='%.3f', padding=5)

# Adding Xticks
plt.xlabel('MPa*mm^4.5*g^-1', fontsize=16)
plt.ylabel('', fontsize=16)
plt.yticks([r + barWidth for r in range(len(cast))], ['Specific Kic', 'Specific Kjc'], fontsize=16)
 
plt.legend(loc='best', fontsize=12)
plt.show()

np.std(layered_K_jc)
# Out:
# 0.5926035259107074

# %%
cast_notched_crosshead = np.array([notched_cast_4.crosshead[-1], notched_cast_5.crosshead[-1], notched_cast_6.crosshead[-1]])
cast_unnotched_crosshead = np.array([flexural_cast_1.crosshead[-1], flexural_cast_2.crosshead[-1], flexural_cast_3.crosshead[-1]])

solid_notched_crosshead = np.array([notched_solid_4.crosshead[-1], notched_solid_5.crosshead[-1], notched_solid_6.crosshead[-1]])
solid_unnotched_crosshead = np.array([flexural_solid_1.crosshead[-1], flexural_solid_2.crosshead[-1], flexural_solid_3.crosshead[-1]])

layered_notched_crosshead = np.array([notched_layered_4.crosshead[-1], notched_layered_6.crosshead[-1]])
layered_unnotched_crosshead = np.array([flexural_layered_1.crosshead[-1], flexural_layered_2.crosshead[-1], flexural_layered_3.crosshead[-1]])

rebar_unnotched_crosshead = np.array([flexural_rebar_1.crosshead[-1], flexural_rebar_2.crosshead[-1], flexural_rebar_3.crosshead[-1]])


cast_notched_extenso = np.array([notched_cast_4.extenso[-1], notched_cast_5.extenso[-1], notched_cast_6.extenso[-1]])
solid_notched_extenso = np.array([notched_solid_4.extenso[-1], notched_solid_5.extenso[-1], notched_solid_6.extenso[-1]])
layered_notched_extenso = np.array([notched_layered_4.extenso[-1], notched_layered_6.extenso[-1]])

# %%
barWidth = 0.25
fig, ax = plt.subplots(figsize=(8, 5))

plt.suptitle('Ultimate Crosshead Displacement', fontsize=24)


cast = np.array([np.mean(cast_notched_crosshead), np.mean(cast_unnotched_crosshead)])
solid = np.array([np.mean(solid_notched_crosshead), np.mean(solid_unnotched_crosshead)])
layered = np.array([np.mean(layered_notched_crosshead), np.mean(layered_unnotched_crosshead)])
rebar = np.array([0, np.mean(rebar_unnotched_crosshead)])


# Set position of bar on X axis
br1 = np.arange(len(cast))*(1+barWidth)
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
br4 = [x + barWidth for x in br3]

n = 3
cast_err = (1.96/np.sqrt(n))*np.array([np.std(cast_notched_crosshead), np.std(cast_unnotched_crosshead)])
solid_err = (1.96/np.sqrt(n))*np.array([np.std(solid_notched_crosshead), np.std(solid_unnotched_crosshead)])
layered_err = (1.96/np.sqrt(n))*np.array([np.std(layered_notched_crosshead), np.std(layered_unnotched_crosshead)])
rebar_err = (1.96/np.sqrt(n))*np.array([0, np.std(rebar_unnotched_crosshead)])

# Make the plot
bar1 = ax.barh(br1, cast, color='b', height=barWidth, edgecolor ='grey', label ='Cast Cement', xerr=cast_err, capsize=5)
ax.bar_label(bar1, fmt='%.2f', padding=5)
bar2 = ax.barh(br2, solid, color='r', height=barWidth, edgecolor ='grey', label ='3DP Cement', xerr=solid_err, capsize=5)
ax.bar_label(bar2, fmt='%.2f', padding=5)
bar3 = ax.barh(br3, layered, color='g', height=barWidth, edgecolor ='grey', label ='3DP Cement-Silicone', xerr=layered_err, capsize=5)
ax.bar_label(bar3, fmt='%.2f', padding=5)
bar4 = ax.barh(br4, rebar, color='#ffb266', height=barWidth, edgecolor ='grey', label ='3DP Cement-PLA', xerr=rebar_err, capsize=5)
ax.bar_label(bar4, fmt='%.2f', padding=5)

# Adding Xticks
plt.xlabel('mm', fontsize=16)
plt.ylabel('', fontsize=16)
plt.yticks([1.25*r + 1.5*barWidth for r in range(len(cast))], ['Notched', 'Unnotched'], fontsize=16)
 
plt.legend()
plt.show()

# %%
barWidth = 0.25
fig, ax = plt.subplots(figsize=(8, 5))

plt.suptitle('Ultimate CMOD', fontsize=24)


cast = np.array([np.mean(cast_notched_extenso)])
solid = np.array([np.mean(solid_notched_extenso)])
layered = np.array([np.mean(layered_notched_extenso)])


# Set position of bar on X axis
br1 = np.arange(len(cast))*(1+barWidth)
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]

n = 3
cast_err = (1.96/np.sqrt(n))*np.array([np.std(cast_notched_extenso)])
solid_err = (1.96/np.sqrt(n))*np.array([np.std(solid_notched_extenso)])
layered_err = (1.96/np.sqrt(n))*np.array([np.std(layered_notched_extenso)])

# Make the plot
bar1 = ax.barh(br1, cast, color='b', height=barWidth, edgecolor ='grey', label ='Cast Cement', xerr=cast_err, capsize=5)
ax.bar_label(bar1, fmt='%.2f', padding=5)
bar2 = ax.barh(br2, solid, color='r', height=barWidth, edgecolor ='grey', label ='3DP Cement', xerr=solid_err, capsize=5)
ax.bar_label(bar2, fmt='%.2f', padding=5)
bar3 = ax.barh(br3, layered, color='g', height=barWidth, edgecolor ='grey', label ='3DP Cement-Silicone', xerr=layered_err, capsize=5)
ax.bar_label(bar3, fmt='%.2f', padding=5)


# Adding Xticks
plt.xlabel('mm', fontsize=16)
plt.ylabel('', fontsize=16)
plt.yticks([1*r + 1*barWidth for r in range(len(cast))], ['Notched'], fontsize=16)
 
plt.legend()
plt.show()

# %%
barWidth = 0.25
fig, ax = plt.subplots(figsize=(8, 6))

plt.suptitle('Specific Toughness Values', fontsize=24)


cast = np.array([np.mean(cast_toughness_stress_normalized)])
solid = np.array([np.mean(solid_toughness_stress_normalized)])
layered = np.array([np.mean(layered_toughness_stress_normalized)])
rebar = np.array([np.mean(rebar_toughness_stress_normalized)])


# Set position of bar on X axis
br1 = np.arange(len(cast))*(1+barWidth)
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
br4 = [x + barWidth for x in br3]

n = 3
cast_err = (1.96/np.sqrt(n))*np.array([np.std(cast_toughness_stress_normalized)])
solid_err = (1.96/np.sqrt(n))*np.array([np.std(solid_toughness_stress_normalized)])
layered_err = (1.96/np.sqrt(n))*np.array([np.std(layered_toughness_stress_normalized)])
rebar_err = (1.96/np.sqrt(n))*np.array([np.std(rebar_toughness_stress_normalized)])

# Make the plot
bar1 = ax.barh(br1, cast, color='#3399ff', height=barWidth, edgecolor ='grey', label ='Cast Cement', xerr=cast_err, capsize=5)
ax.bar_label(bar1, fmt='%.3f', padding=5)
bar2 = ax.barh(br2, solid, color='#ff2f2f', height=barWidth, edgecolor ='grey', label ='3DP Cement', xerr=solid_err, capsize=5)
ax.bar_label(bar2, fmt='%.3f', padding=5)
bar3 = ax.barh(br3, layered, color='#36a841', height=barWidth, edgecolor ='grey', label ='3DP Cement-Silicone', xerr=layered_err, capsize=5)
ax.bar_label(bar3, fmt='%.3f', padding=5)
bar4 = ax.barh(br4, rebar, color='#ffb266', height=barWidth, edgecolor ='grey', label ='3DP Cement-PLA', xerr=rebar_err, capsize=5)
ax.bar_label(bar4, fmt='%.2f', padding=5)

# Adding Xticks
plt.xlabel('J/g', fontsize=16)
plt.ylabel('', fontsize=16)
plt.yticks([1.5*barWidth], [''], fontsize=16)
 
plt.legend(loc='lower right', fontsize=12)
plt.show()


np.std(cast_toughness_stress_normalized)
# Out:
# 0.010219408783828422

# %%
barWidth = 0.25
fig, ax = plt.subplots(figsize=(8, 6))

plt.suptitle('Specific Toughness Values (Cement-PLA Excluded)', fontsize=24)


cast = np.array([np.mean(cast_toughness_stress_normalized)])
solid = np.array([np.mean(solid_toughness_stress_normalized)])
layered = np.array([np.mean(layered_toughness_stress_normalized)])


# Set position of bar on X axis
br1 = np.arange(len(cast))*(1+barWidth)
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]

n = 3
cast_err = (1.96/np.sqrt(n))*np.array([np.std(cast_toughness_stress_normalized)])
solid_err = (1.96/np.sqrt(n))*np.array([np.std(solid_toughness_stress_normalized)])
layered_err = (1.96/np.sqrt(n))*np.array([np.std(layered_toughness_stress_normalized)])

# Make the plot
bar1 = ax.barh(br1, cast, color='#3399ff', height=barWidth, edgecolor ='grey', label ='Cast Cement', xerr=cast_err, capsize=5)
ax.bar_label(bar1, fmt='%.3f', padding=5)
bar2 = ax.barh(br2, solid, color='#ff2f2f', height=barWidth, edgecolor ='grey', label ='3DP Cement', xerr=solid_err, capsize=5)
ax.bar_label(bar2, fmt='%.3f', padding=5)
bar3 = ax.barh(br3, layered, color='#36a841', height=barWidth, edgecolor ='grey', label ='3DP Cement-Silicone', xerr=layered_err, capsize=5)
ax.bar_label(bar3, fmt='%.3f', padding=5)
# Adding Xticks
plt.xlabel('J/g', fontsize=16)
plt.ylabel('', fontsize=16)
plt.yticks([1*barWidth], [''], fontsize=16)
 
plt.legend(loc='lower right', fontsize=12)
plt.show()

# %%
barWidth = 0.25
fig, ax = plt.subplots(figsize=(8, 6))

plt.suptitle('Specific MOR Values', fontsize=24)


cast = np.array([np.mean(cast_MOR_normalized)])
solid = np.array([np.mean(solid_MOR_normalized)])
layered = np.array([np.mean(layered_MOR_normalized)])
rebar = np.array([np.mean(rebar_MOR_normalized)])


# Set position of bar on X axis
br1 = np.arange(len(cast))*(1+barWidth)
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
br4 = [x + barWidth for x in br3]

n = 3
cast_err = (1.96/np.sqrt(n))*np.array([np.std(cast_MOR_normalized)])
solid_err = (1.96/np.sqrt(n))*np.array([np.std(solid_MOR_normalized)])
layered_err = (1.96/np.sqrt(n))*np.array([np.std(layered_MOR_normalized)])
rebar_err = (1.96/np.sqrt(n))*np.array([np.std(rebar_MOR_normalized)])

# Make the plot
bar1 = ax.barh(br1, cast, color='#3399ff', height=barWidth, edgecolor ='grey', label ='Cast Cement', xerr=cast_err, capsize=5)
ax.bar_label(bar1, fmt='%.3f', padding=5)
bar2 = ax.barh(br2, solid, color='#ff2f2f', height=barWidth, edgecolor ='grey', label ='3DP Cement', xerr=solid_err, capsize=5)
ax.bar_label(bar2, fmt='%.3f', padding=5)
bar3 = ax.barh(br3, layered, color='#36a841', height=barWidth, edgecolor ='grey', label ='3DP Cement-Silicone', xerr=layered_err, capsize=5)
ax.bar_label(bar3, fmt='%.3f', padding=5)
bar4 = ax.barh(br4, rebar, color='#ffb266', height=barWidth, edgecolor ='grey', label ='3DP Cement-PLA', xerr=rebar_err, capsize=5)
ax.bar_label(bar4, fmt='%.2f', padding=5)

# Adding Xticks
plt.xlabel('MPa*mm^3*g^-1', fontsize=16)
plt.ylabel('', fontsize=16)
plt.yticks([1.5*barWidth], [''], fontsize=16)
 
plt.legend(loc='lower right', fontsize=12)
plt.show()


np.array([np.std(layered_MOR_normalized)])
# Out:
# array([0.0091696])

# %%
barWidth = 0.25
fig, ax = plt.subplots(figsize=(8, 6))

plt.suptitle('Specific MOR Values (Cement-PLA Excluded)', fontsize=24)


cast = np.array([np.mean(cast_MOR_normalized)])
solid = np.array([np.mean(solid_MOR_normalized)])
layered = np.array([np.mean(layered_MOR_normalized)])


# Set position of bar on X axis
br1 = np.arange(len(cast))*(1+barWidth)
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
br4 = [x + barWidth for x in br3]

n = 3
cast_err = (1.96/np.sqrt(n))*np.array([np.std(cast_MOR_normalized)])
solid_err = (1.96/np.sqrt(n))*np.array([np.std(solid_MOR_normalized)])
layered_err = (1.96/np.sqrt(n))*np.array([np.std(layered_MOR_normalized)])

# Make the plot
bar1 = ax.barh(br1, cast, color='#3399ff', height=barWidth, edgecolor ='grey', label ='Cast Cement', xerr=cast_err, capsize=5)
ax.bar_label(bar1, fmt='%.3f', padding=5)
bar2 = ax.barh(br2, solid, color='#ff2f2f', height=barWidth, edgecolor ='grey', label ='3DP Cement', xerr=solid_err, capsize=5)
ax.bar_label(bar2, fmt='%.3f', padding=5)
bar3 = ax.barh(br3, layered, color='#36a841', height=barWidth, edgecolor ='grey', label ='3DP Cement-Silicone', xerr=layered_err, capsize=5)
ax.bar_label(bar3, fmt='%.3f', padding=5)

# Adding Xticks
plt.xlabel('MPa*mm^3*g^-1', fontsize=16)
plt.ylabel('', fontsize=16)
plt.yticks([1.5*barWidth], [''], fontsize=16)
 
plt.legend(loc='upper right', fontsize=12)
plt.show()

# %% [markdown]
# ####
